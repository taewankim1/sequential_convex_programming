# %%
import matplotlib.pyplot as plt
# %matplotlib inline  
# %load_ext autoreload
# %autoreload 2
import numpy as np
import time
import random
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
#     print ("Values are: \n%s" % (x))

# %%
import sys
# sys.path.append('../')
sys.path.append('../')
sys.path.append('../model')
sys.path.append('../cost')
sys.path.append('../constraints')
import Landing2DModel
import Landing2DCost
import Landing2DConstraints
from scipy.integrate import solve_ivp
from Scvx import Scvx

# %%
ix = 6
iu = 2
ih = 9
N = 50
delT = 0.1
max_iter = 20

# %%
xi = np.array([2,4,0,-0.1,np.deg2rad(30),0])
xf = np.array([0,0,0,0,0,0])


myModel = Landing2DModel.Landing2D('Hello',ix,iu,delT)
myCost = Landing2DCost.Landing2D('Hello',ix,iu,N)
myConst = Landing2DConstraints.Landing2D('Hello',ix,iu,ih)

x0 = np.zeros((N+1,ix))
for i in range(N+1) :
    x0[i] = (N-i)/N * xi + i/N * xf
# u0 = np.random.rand(N,iu)
u0 = np.zeros((N+1,iu))
# u0[:,0] = 0
u0[:,1] = 2

# %%
i1 = Scvx('unicycle',N,max_iter,myModel,myCost,myConst,type_discretization="zoh")#,w_vc=1e4,w_tr=1e-3)
x,u,xbar,ubar,num_iter = i1.update(x0,u0,xi,xf)
# Out:
# --------------------------------------------------------
# IndexError             Traceback (most recent call last)
# <ipython-input-16-e5fcaf39fef4> in <module>
#       1 i1 = Scvx('unicycle',N,max_iter,myModel,myCost,myConst,type_discretization="zoh")#,w_vc=1e4,w_tr=1e-3)
# ----> 2 x,u,xbar,ubar,num_iter = i1.update(x0,u0,xi,xf)
#
# ~/Documents/Code/Personal/Scvx/Scvx.py in update(self, x0, u0, xi, xf)
#     235             # step2. cvxopt
#     236             try :
# --> 237                 prob_status,l,l_vc,l_tr,self.xbar,self.ubar,self.vcnew, self.trnew = self.cvxopt()
#     238             except cvx.SolverError :
#     239                 print("FAIL : Solver fail")
#
# ~/Documents/Code/Personal/Scvx/Scvx.py in cvxopt(self)
#     134         for i in range(N+1) :
#     135             constraints.append(cvx.quad_form(x_cvx[i] - iSx@(self.x[i]-sx),np.eye(ix)) + \
# --> 136              cvx.quad_form(u_cvx[i]-iSu@(self.u[i]-su),np.eye(iu)) <= tr[i] )
#     137
#     138         # inequality contraints
#
# IndexError: index 50 is out of bounds for axis 0 with size 50

# %%
from utils import plot_Landing2D_trajectory
    
plot_Landing2D_trajectory(xbar,ubar,x,delT)

# %%
from utils import make_rocket2d_trajectory_fig
make_rocket2d_trajectory_fig(xbar,ubar,'Landing2D')

# %%
from sympy import sin, cos, Matrix
import sympy as sym

# %%
# X = Matrix([rho*cos(phi), rho*sin(phi), rho**2])
# Y = Matrix([rho, phi])

# X.jacobian(Y)

m,g,I,rx,ry,vx,vy,t,w,r_t = sym.symbols('m,g,I,rx,ry,vx,vy,t,w,r_t')
gimbal,thrust = sym.symbols('gimbal,thrust')

f1 = vx
f2 = vy
f3 = 1/m * (-sin(t+gimbal))*thrust
f4 = 1/m * (cos(t+gimbal))*thrust - g
f5 = w
f6 = 1/I * (-sin(gimbal)*thrust*r_t)
f = Matrix([f1,f2,f3,f4,f5,f6])
state = [rx,ry,vx,vy,t,w]
input = [gimbal,thrust]

# %%
f.jacobian(state)

# %%
f.jacobian(input)

# %%
from sympy.tensor.array import derive_by_array

# %%
derive_by_array(f.jacobian(input))
