# %%
import matplotlib.pyplot as plt
# %matplotlib inline  
# %load_ext autoreload
# %autoreload 2
import numpy as np
import time
import random
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
#     print ("Values are: \n%s" % (x))

# %%
import sys
# sys.path.append('../')
sys.path.append('../')
sys.path.append('../model')
sys.path.append('../cost')
sys.path.append('../constraints')
import Landing2DModel
import Landing2DCost
import Landing2DConstraints
from scipy.integrate import solve_ivp
from Scvx import Scvx

# %%
ix = 6
iu = 2
ih = 9
N = 100
delT = 0.1
max_iter = 100

# %%
xi = np.array([4,4,-2,-1,0,0])
xf = np.array([0,0,0,0,0,0])


myModel = Landing2DModel.Landing2D('Hello',ix,iu,delT)
myCost = Landing2DCost.Landing2D('Hello',ix,iu,N)
myConst = Landing2DConstraints.Landing2D('Hello',ix,iu,ih)

x0 = np.zeros((N+1,ix))
for i in range(N+1) :
    x0[i] = (N-i)/N * xi + i/N * xf
# u0 = np.random.rand(N,iu)
u0 = np.zeros((N,iu))
# u0[:,0] = 0
u0[:,1] = 2

# %%
i1 = Scvx('unicycle',N,max_iter,myModel,myCost,myConst)
x, u = i1.update(x0,u0)
# Out:
# Boundary conditions are not satisified: just accept this step
# iteration   cost        cost_vc   cost_tr   reduction    expected    radius_tr
# 0           0           6e+05       0           6e+05       6e+05       1.0
# Boundary conditions are not satisified: just accept this step
# 1           0           1.22e-08    26.6        20          20          2.0
# Boundary conditions are not satisified: just accept this step
# 2           0           2.31e-08    6.59        4.06        4.06        4.0
# Boundary conditions are not satisified: just accept this step
# 3           0           2.98e-08    2.53        1.02        1.02        8.0
# Boundary conditions are not satisified: just accept this step
# 4           0           3.93e-08    1.51        0.926       0.926       16.0
# Boundary conditions are not satisified: just accept this step
# 5           0           1.26e-09    0.586       0.244       0.244       32.0
# Boundary conditions are not satisified: just accept this step
# 6           0           1.82e-09    0.342       0.22        0.22        64.0
# Boundary conditions are not satisified: just accept this step
# 7           0           4.99e-09    0.122       0.0543      0.0543      128.0
# Boundary conditions are not satisified: just accept this step
# 8           0           6.02e-09    0.068       0.0427      0.0427      256.0
# Boundary conditions are not satisified: just accept this step
# 9           0           4.56e-09    0.0253      0.0108      0.0108      512.0
# Boundary conditions are not satisified: just accept this step
# 10          0           2.66e-09    0.0145      0.00885     0.00885     1024.0
# Boundary conditions are not satisified: just accept this step
# 11          0           2.77e-09    0.00562     0.00275     0.00275     2048.0
# Boundary conditions are not satisified: just accept this step
# 12          0           1.8e-09     0.00287     0.0018      0.0018      4096.0
# Boundary conditions are not satisified: just accept this step
# 13          0           2.44e-08    0.00108     0.000515    0.000515    8192.0
# Boundary conditions are not satisified: just accept this step
# 14          0           2.33e-08    0.000561    0.000373    0.000373    16384.0
# Boundary conditions are not satisified: just accept this step
# 15          0           4.62e-09    0.000188    0.000113    0.000113    32768.0
# Boundary conditions are not satisified: just accept this step
# 16          0           3.43e-09    7.44e-05    4.58e-05    4.58e-05    65536.0
# Boundary conditions are not satisified: just accept this step
# 17          0           6.2e-09     2.86e-05    1.36e-05    1.36e-05    131072.0
# 18          0           3.23e-08    1.5e-05     1.45e-05    1.45e-05    131072.0
# SUCCEESS: cost change < tolFun 1.4534230415372783e-05

# %%
fS = 18
Fx = +np.sin(x[:N,4] + u[:,0]) * u[:,1]
Fy = -np.cos(x[:N,4] + u[:,0]) * u[:,1]
plt.figure(figsize=(10,10))
plt.plot(x[:,0], x[:,1], linewidth=2.0)
plt.gca().set_aspect('equal', adjustable='box')
index = np.linspace(0,N-1,30)
index = [int(i) for i in index]
plt.quiver(x[index,0], x[index,1], -np.sin(x[index,4]), np.cos(x[index,4]), color='blue', width=0.003, scale=15, headwidth=1, headlength=0)
plt.quiver(x[index,0], x[index,1], Fx[index], Fy[index], color='red', width=0.003, scale=100, headwidth=1, headlength=0)
plt.axis([-2, 5, -1, 5])
plt.xlabel('X (m)', fontsize = fS)
plt.ylabel('Y (m)', fontsize = fS)

plt.figure(figsize=(10,15))
plt.subplot(321)
plt.plot(np.array(range(N+1))*delT, x[:,0], linewidth=2.0,label='naive')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('rx ()', fontsize = fS)
plt.subplot(322)
plt.plot(np.array(range(N+1))*delT, x[:,1], linewidth=2.0,label='naive')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('ry ()', fontsize = fS)
plt.subplot(323)
plt.plot(np.array(range(N+1))*delT, x[:,2], linewidth=2.0,label='naive')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('vx ()', fontsize = fS)
plt.subplot(324)
plt.plot(np.array(range(N+1))*delT, x[:,3], linewidth=2.0,label='naive')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('vy ()', fontsize = fS)
plt.legend(fontsize=fS)
plt.subplot(325)
plt.plot(np.array(range(N+1))*delT, x[:,4], linewidth=2.0,label='naive')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('theta (rad)', fontsize = fS)
plt.subplot(326)
plt.plot(np.array(range(N+1))*delT, x[:,5], linewidth=2.0,label='naive')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('theta dot (rad/s)', fontsize = fS)
plt.legend(fontsize=fS)
plt.show()

plt.figure()
plt.subplot(121)
plt.plot(np.array(range(N))*delT, u[:,0], linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('gimbal (rad)', fontsize = fS)
plt.subplot(122)
plt.plot(np.array(range(N))*delT, u[:,1], linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('thrust ()', fontsize = fS)
plt.show()

# %%
import imageio
import os

# %%
Fx = +np.sin(x[:N,4] + u[:,0]) * u[:,1]
Fy = -np.cos(x[:N,4] + u[:,0]) * u[:,1]
filenames = []
for i in range(N+1) :
    fS = 18
    plt.figure(figsize=(10,10))
    plt.gca().set_aspect('equal', adjustable='box')
    index = i
    plt.plot(x[:i+1,0], x[:i+1,1], linewidth=2.0) 
    plt.plot(0, 0,'*', linewidth=2.0)
    plt.quiver(x[index,0], x[index,1], -np.sin(x[index,4]), np.cos(x[index,4]), color='blue', width=0.003, scale=15, headwidth=1, headlength=0)
    if i < N :
        plt.quiver(x[index,0], x[index,1], Fx[index], Fy[index], color='red', width=0.003, scale=100, headwidth=1, headlength=0)
    plt.axis([-2, 5, -1, 5])
    plt.xlabel('X (m)', fontsize = fS)
    plt.ylabel('Y (m)', fontsize = fS)
    filename = '../images/{:d}.png'.format(i)
    plt.savefig(filename)
    filenames.append(filename)
    plt.close()

# %%
with imageio.get_writer('../images/mygif.gif', mode='I') as writer:
    for filename in filenames:
        image = imageio.imread(filename)
        writer.append_data(image)
for filename in set(filenames):
    os.remove(filename)
