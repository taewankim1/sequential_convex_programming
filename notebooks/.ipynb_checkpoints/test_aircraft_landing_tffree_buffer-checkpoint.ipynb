# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib qt
# %load_ext autoreload
# %autoreload 2
import numpy as np
import time
import random
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
#     print ("Values are: \n%s" % (x))

# %%
import sys
# sys.path.append('../')
sys.path.append('../')
sys.path.append('../model')
sys.path.append('../cost')
sys.path.append('../constraints')
sys.path.append('../utils')
import Aircraft3dofModel
import FinaltimeFreeCost
import Aircraft3dofConstraints
from scipy.integrate import solve_ivp
from Scvx_tf_free_buffer import Scvx_tf_free_buffer
from Scvx_tf_free import Scvx_tf_free
from Scaling import TrajectoryScaling

# %%
ix = 6
iu = 3
tf = 500
N = 50
delT = tf/N
max_iter = 50

# %%
myModel = Aircraft3dofModel.Aircraft3dof('Hello',ix,iu,linearization="analytic")
myCost = FinaltimeFreeCost.Finaltime('Hello',ix,iu,N)
myConst = Aircraft3dofConstraints.Aircraft3dof('Hello',ix,iu)

x_min = np.zeros(ix)
x_max = np.array([110*1e3,60*1e3,10*1e3,240,np.deg2rad(20),np.pi/2])
u_min = np.array([0,0,0])
u_max = np.array([1.52,np.deg2rad(15),1126.3 * 1e3])

myScaling = TrajectoryScaling(x_min,x_max,u_min,u_max,tf)

# %%
xi = np.array([0*1e3,0*1e3,10*1e3,240,0,0])
xf = np.array([110*1e3,-60*1e3,0,95,-np.deg2rad(3),np.deg2rad(80)])
# xf = np.array([110*1e3,-0*1e3,0,95,-np.deg2rad(0),np.deg2rad(0)])

x0 = np.zeros((N+1,ix))
for i in range(N+1) :
    x0[i] = (N-i)/N * xi + i/N * xf

u0 = np.zeros((N+1,iu))
ui = np.array([0.0,np.deg2rad(0),0])
uf = np.array([0.0,-np.deg2rad(0),0])
for i in range(N+1) :
    u0[i] = (N-i)/N * ui + i/N * uf
for i in range(0,27) :
    u0[i,0] = (26-i)/26 * 0.3 + i/26 * 0.15
for i in range(27,N+1) :
    u0[i,0] = 1/700 * (i-27)**2 + 0.15

# %%
i1 = Scvx_tf_free_buffer('aircraft',N,tf,max_iter,myModel,myCost,myConst,myScaling,
          type_discretization='zoh',w_c=1,w_bf=1e5,w_tr=1e-2,tol_bf=1e-6,tol_tr=1e-5,tol_bc=1,flag_policyopt=False)
x,u,xbar,ubar,tfbar,total_num_iter,flag_boundary,l,l_vc,l_tr,x_traj,u_traj = i1.run(x0,u0,xi,xf)
# Out:
# iteration   total_cost        cost        ||bf||     ||tr||       reduction   w_tr        bounary
# 1           442525.115        377.550     4.42        834         -4.42e+05   0.010000    0(7.25e+04)
# non-positive expected reduction
# 2           780509.135        477.219     7.8         991         -3.38e+05   0.010000    0(1.29e+05)
# 3           3265.709          632.590     0.0262      1.33e+03    7.77e+05    0.010000    0(8.79e+04)
# /Users/keemtw/opt/anaconda3/envs/py310/lib/python3.10/site-packages/cvxpy/problems/problem.py:1296: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# WARNING: inaccurate solution
# 4           540.116           534.836     3.31e-06    495         2.73e+03    0.010000    0(8.33e+04)
# non-positive expected reduction
# 5           3424.296          519.671     0.029       121         -2.88e+03   0.010000    0(6.37e+04)
# WARNING: inaccurate solution
# 6           492.914           491.568     2.79e-06    107         2.93e+03    0.010000    0(3.62e+04)
# WARNING: inaccurate solution
# non-positive expected reduction
# 7           515.095           513.196     3.96e-06    150         -22.2       0.010000    0(4.32e+04)
# WARNING: inaccurate solution
# 8           489.222           487.735     3.87e-06    110         25.9        0.010000    0(2.34e+04)
# non-positive expected reduction
# 9           498.796           497.191     2.39e-06    137         -9.57       0.010000    0(3.6e+04)
# 10          490.672           489.123     2.53e-06    130         8.12        0.010000    0(2.45e+04)
# WARNING: inaccurate solution
# non-positive expected reduction
# 11          509.192           507.460     3.01e-06    143         -18.5       0.010000    0(3.11e+04)
# WARNING: inaccurate solution
# 12          490.811           489.093     5.5e-06     117         18.4        0.010000    0(2.57e+04)
# 13          488.666           487.341     1.85e-06    114         2.14        0.010000    0(3.44e+04)
# 14          485.085           484.070     1.12e-06    90.4        3.58        0.010000    0(2.67e+04)
# non-positive expected reduction
# 15          503.455           502.156     1.82e-06    112         -18.4       0.010000    0(3.22e+04)
# WARNING: inaccurate solution
# 16          487.229           485.829     5.42e-06    85.8        16.2        0.010000    0(2.11e+04)
# WARNING: inaccurate solution
# non-positive expected reduction
# 17          516.298           514.751     2.58e-06    129         -29.1       0.010000    0(4.11e+04)
# 18          489.559           488.454     1.72e-06    93.3        26.7        0.010000    0(1.79e+04)
# WARNING: inaccurate solution
# non-positive expected reduction
# 19          525.011           522.998     4.4e-06     157         -35.5       0.010000    0(3.36e+04)
# WARNING: inaccurate solution
# 20          487.845           486.425     3.17e-06    110         37.2        0.010000    0(1.64e+04)
# WARNING: inaccurate solution
# non-positive expected reduction
# 21          536.437           533.963     5.81e-06    189         -48.6       0.010000    0(4.47e+04)
# 22          488.707           486.931     2.39e-06    154         47.7        0.010000    0(1.82e+04)
# WARNING: inaccurate solution
# non-positive expected reduction
# 23          535.723           533.305     3.99e-06    202         -47         0.010000    0(5.09e+04)
# WARNING: inaccurate solution
# 24          488.112           486.145     3.79e-06    159         47.6        0.010000    0(1.88e+04)
# WARNING: inaccurate solution
# non-positive expected reduction
# 25          547.182           544.612     3.04e-06    227         -59.1       0.010000    0(2.19e+04)
# WARNING: inaccurate solution
# 26          512.066           510.136     3.04e-06    163         35.1        0.010000    0(2.18e+04)
# WARNING: inaccurate solution
# 27          489.480           487.911     3.09e-06    126         22.6        0.010000    0(2.66e+04)
# 28          486.152           484.963     1.24e-06    106         3.33        0.010000    0(3.18e+04)
# WARNING: inaccurate solution
# 29          485.222           483.839     2.41e-06    114         0.929       0.010000    0(3.25e+04)
# non-positive expected reduction
# 30          485.419           484.125     1.31e-06    116         -0.197      0.010000    0(3.23e+04)
# WARNING: inaccurate solution
# non-positive expected reduction
# 31          485.755           484.315     2.1e-06     123         -0.336      0.010000    0(3.33e+04)
# 32          485.544           484.243     1.09e-06    119         0.211       0.010000    0(3.06e+04)
# non-positive expected reduction
# 33          486.822           485.371     1.72e-06    128         -1.28       0.010000    0(3.4e+04)
# 34          485.312           483.953     1.96e-06    116         1.51        0.010000    0(2.84e+04)
# non-positive expected reduction
# 35          497.255           495.678     2.37e-06    134         -11.9       0.010000    0(3.69e+04)
# 36          488.203           487.038     2.07e-06    95.8        9.05        0.010000    0(2.44e+04)
# WARNING: inaccurate solution
# non-positive expected reduction
# 37          529.080           527.044     3.97e-06    164         -40.9       0.010000    0(3.2e+04)
# WARNING: inaccurate solution
# 38          488.215           486.178     4.99e-06    154         40.9        0.010000    0(1.79e+04)
# WARNING: inaccurate solution
# non-positive expected reduction
# 39          527.819           525.643     5.47e-06    163         -39.6       0.010000    0(3.29e+04)
# WARNING: inaccurate solution
# 40          489.089           487.275     4.15e-06    140         38.7        0.010000    0(1.67e+04)
# WARNING: inaccurate solution
# non-positive expected reduction
# 41          530.901           528.654     4.7e-06     178         -41.8       0.010000    0(3.26e+04)
# 42          487.986           486.343     2.38e-06    140         42.9        0.010000    0(1.79e+04)
# WARNING: inaccurate solution
# non-positive expected reduction
# 43          530.179           528.088     5.18e-06    157         -42.2       0.010000    0(2.66e+04)
# WARNING: inaccurate solution
# 44          486.700           485.023     2.85e-06    139         43.5        0.010000    0(1.73e+04)
# WARNING: inaccurate solution
# non-positive expected reduction
# 45          518.352           516.259     6.77e-06    142         -31.7       0.010000    0(4.99e+04)
# 46          488.040           486.850     1.81e-06    101         30.3        0.010000    0(1.74e+04)
# WARNING: inaccurate solution
# non-positive expected reduction
# 47          547.485           544.737     4.87e-06    226         -59.4       0.010000    0(2.77e+04)
# WARNING: inaccurate solution
# 48          491.144           488.478     3.95e-06    227         56.3        0.010000    0(2.56e+04)
# KeyboardInterrupt

# %%
print(tfbar)
# Out:
# 464.9463745723039

# %%
fig = plt.figure(1,figsize=(15,7))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

ax.plot(x[:, 0], x[:, 1], x[:, 2],label='single shooting')
ax.plot(xbar[:, 0], xbar[:, 1], xbar[:, 2],label='solution')
plt.legend()
fig = plt.figure(2,figsize=(15,7))
ax = fig.add_subplot(121)
ax.plot(x[:, 0], x[:, 1],label='single shooting')
ax.plot(xbar[:, 0], xbar[:, 1],label='solution')
ax.set_xlabel('X')
ax.set_ylabel('Y')
plt.legend()
ax = fig.add_subplot(122)
ax.plot(x[:, 1], x[:, 2],label='single shooting')
ax.plot(xbar[:, 1], xbar[:, 2],label='solution')
ax.set_xlabel('Y')


ax.set_ylabel('Z')
plt.legend()
# ax.plot(xbar[:, 0], xbar[:, 1], xbar[:, 2],'o')

# %%
t_index = np.array([i for i in range(N+1)]) / N * tfbar
plt.figure(figsize=(15,15))
plt.subplot(331)
plt.plot(t_index,xbar[:,0])
plt.plot(t_index,x[:,0],'--')
plt.title('x (m)')

plt.subplot(332)
plt.plot(t_index,xbar[:,1])
plt.plot(t_index,x[:,1],'--')
plt.title('y (m)')

plt.subplot(333)
plt.plot(t_index,xbar[:,2])
plt.plot(t_index,x[:,2],'--')
plt.title('z (m)')


plt.subplot(334)
plt.plot(t_index,xbar[:,3])
plt.plot(t_index,x[:,3],'--')
plt.title('velocity (m/s)')

plt.subplot(335)
plt.plot(t_index,xbar[:,4])
plt.plot(t_index,x[:,4],'--')
plt.title('gamma (rad)')

plt.subplot(336)
plt.plot(t_index,xbar[:,5])
plt.plot(t_index,x[:,5],'--')
plt.title('psi (rad)')

plt.subplot(337)
plt.plot(t_index,ubar[:,0])
plt.plot(t_index,u0[:,0],'--')
plt.plot(t_index,ubar[:,2]*0 + myConst.CL_max,'--',color='tab:red')
plt.plot(t_index,ubar[:,2]*0 + myConst.CL_min,'--',color='tab:red')
plt.title('CL')

plt.subplot(338)
plt.plot(t_index,ubar[:,1])
plt.plot(t_index,ubar[:,2]*0 + myConst.phi_max,'--',color='tab:red')
plt.plot(t_index,ubar[:,2]*0 + myConst.phi_min,'--',color='tab:red')
plt.title('phi (rad)')

plt.subplot(339)
plt.plot(t_index,ubar[:,2])
plt.plot(t_index,ubar[:,2]*0 + myConst.T_max,'--',color='tab:red')
plt.plot(t_index,ubar[:,2]*0 + myConst.T_min,'--',color='tab:red')
plt.title('thrust (N)')
# Out:
# Text(0.5, 1.0, 'thrust (N)')

# %%
for ubar_ in u_traj :
    plt.plot(t_index,ubar_[:,0],alpha=0.5,color='tab:blue')
plt.title('CL')
