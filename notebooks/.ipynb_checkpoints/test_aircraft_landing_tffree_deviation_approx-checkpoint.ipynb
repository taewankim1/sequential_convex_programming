# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib qt
# %load_ext autoreload
# %autoreload 2
import numpy as np
import time
import random
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
#     print ("Values are: \n%s" % (x))

# %%
import sys
# sys.path.append('../')
sys.path.append('../')
sys.path.append('../model')
sys.path.append('../cost')
sys.path.append('../constraints')
sys.path.append('../utils')
import Aircraft3dofApproxModel
import FinaltimeFreeCost
import Aircraft3dofConstraints
from scipy.integrate import solve_ivp
from SCP_buffer_deviation import SCP_buffer_deviation
from Scaling import TrajectoryScaling

# %%
ix = 6
iu = 3
tf = 600
N = 50
delT = tf/N
max_iter = 50

# %%
myModel = Aircraft3dofApproxModel.Aircraft3dofApproxModel('Hello',ix,iu,linearization="numeric_central")
myCost = FinaltimeFreeCost.Finaltime('Hello',ix,iu,N)
myConst = Aircraft3dofConstraints.Aircraft3dof('Hello',ix,iu)

x_min = np.zeros(ix)
x_max = np.array([110*1e3,60*1e3,10*1e3,240,np.deg2rad(20),np.pi/2])
u_min = np.array([0,0,0])
u_max = np.array([1.52,np.deg2rad(15),1126.3 * 1e3]) 

myScaling = TrajectoryScaling(x_min,x_max,u_min,u_max,tf)

# %%
xi = np.array([0*1e3,0*1e3,10*1e3,240,0,0])
xf = np.array([110*1e3,-60*1e3,0,95,-np.deg2rad(3),np.deg2rad(80)])
# xf = np.array([110*1e3,-0*1e3,0,95,-np.deg2rad(0),np.deg2rad(0)])

x0 = np.zeros((N+1,ix))
for i in range(N+1) :
    x0[i] = (N-i)/N * xi + i/N * xf

u0 = np.zeros((N+1,iu))
ui = np.array([0.5,np.deg2rad(15),0])
uf = np.array([0.5,-np.deg2rad(-15),0])
for i in range(N+1) :
    u0[i] = (N-i)/N * ui + i/N * uf
# idx_c = int(26 * N / 50)
# for i in range(0,idx_c+1) :
#     u0[i,0] = (idx_c-i)/idx_c * 0.3 + i/idx_c * 0.15
# for i in range(idx_c+1,N+1) :
#     u0[i,0] = 1/700* (i-idx_c-1)**2 + 0.15

# %%
# w_tr for time is 1
i1 = SCP_buffer_deviation('hello',N,tf,max_iter,myModel,myCost,myConst,myScaling,
          type_discretization="foh",w_c=1,w_bf=1e6,w_bf_b=1e6,w_tr=1e3,tol_bf=1e-6,tol_tr=1e-6,tol_bc=1)
x,u,xbar,ubar,Tbar,total_num_iter,flag_boundary,l,l_vc,l_tr,x_traj,u_traj  = i1.run(x0,u0,xi,xf)
# Out:
# iteration   total_cost        cost        ||bf||     ||tr||       reduction   w_tr        bounary
# 1           10443.702         516.00000   2.04e-06    99.3        -9.84e+03   100.000000  0(2.2e+05)
# 2           3888.197          585.92820   7.72e-07    33          6.56e+03    100.000000  0(4.63e+07)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/tm/mswbc_xs6x7grdqhyvcpdhw80000gn/T/ipykernel_44466/3011004309.py in <module>
#       2 i1 = SCP_buffer_deviation('hello',N,tf,max_iter,myModel,myCost,myConst,myScaling,
#       3           type_discretization="foh",w_c=1,w_bf=1e6,w_bf_b=1e6,w_tr=1e2,tol_bf=1e-6,tol_tr=1e-6,tol_bc=1)
# ----> 4 x,u,xbar,ubar,Tbar,total_num_iter,flag_boundary,l,l_vc,l_tr,x_traj,u_traj  = i1.run(x0,u0,xi,xf)
#       5
#
# ~/Documents/Code/Personal/Scvx/notebooks/../SCP_buffer_deviation.py in run(self, x0, u0, xi, xf, u_const)
#     248             # step2. cvxopt
#     249             # try :
# --> 250             prob_status,l,l_bf,l_tr,self.xbar,self.ubar,self.Tbar,error = self.cvxopt(self.x,self.u,self.T,self.x_prop)
#     251             if error == True :
#     252                 total_num_iter = 1e5
#
# ~/Documents/Code/Personal/Scvx/notebooks/../SCP_buffer_deviation.py in cvxopt(self, x, u, T, x_prop)
#     159         # prob.solve(verbose=False,solver=cvx.OSQP)#,eps_abs=1e-3,eps_rel=1e-3)
#     160         # prob.solve(verbose=False,solver=cvx.ECOS)
# --> 161         prob.solve(verbose=False,solver=cvx.GUROBI)
#     162
#     163         if prob.status == cvx.OPTIMAL_INACCURATE :
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/cvxpy/problems/problem.py in solve(self, *args, **kwargs)
#     471         else:
#     472             solve_func = Problem._solve
# --> 473         return solve_func(self, *args, **kwargs)
#     474
#     475     @classmethod
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/cvxpy/problems/problem.py in _solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, **kwargs)
#     964                 return self.value
#     965
# --> 966         data, solving_chain, inverse_data = self.get_problem_data(
#     967             solver, gp, enforce_dpp, verbose)
#     968
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/cvxpy/problems/problem.py in get_problem_data(self, solver, gp, enforce_dpp, verbose)
#     625                          'Compiling problem (target solver=%s).', solver_name)
#     626                 s.LOGGER.info('Reduction chain: %s', reduction_chain_str)
# --> 627             data, inverse_data = solving_chain.apply(self, verbose)
#     628             safe_to_cache = (
#     629                 isinstance(data, dict)
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/cvxpy/reductions/chain.py in apply(self, problem, verbose)
#      74             if verbose:
#      75                 s.LOGGER.info('Applying reduction %s', type(r).__name__)
# ---> 76             problem, inv = r.apply(problem)
#      77             inverse_data.append(inv)
#      78         return problem, inverse_data
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/cvxpy/reductions/qp2quad_form/qp2symbolic_qp.py in apply(self, problem)
#      58         if not self.accepts(problem):
#      59             raise ValueError("Cannot reduce problem to symbolic QP")
# ---> 60         return super(Qp2SymbolicQp, self).apply(problem)
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/cvxpy/reductions/canonicalization.py in apply(self, problem)
#      65             # generated while canonicalizing the arguments of the original
#      66             # constraint
# ---> 67             canon_constr, aux_constr = self.canonicalize_tree(
#      68                 constraint)
#      69             canon_constraints += aux_constr + [canon_constr]
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/cvxpy/reductions/canonicalization.py in canonicalize_tree(self, expr)
#      97             constrs = []
#      98             for arg in expr.args:
# ---> 99                 canon_arg, c = self.canonicalize_tree(arg)
#     100                 canon_args += [canon_arg]
#     101                 constrs += c
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/cvxpy/reductions/canonicalization.py in canonicalize_tree(self, expr)
#      97             constrs = []
#      98             for arg in expr.args:
# ---> 99                 canon_arg, c = self.canonicalize_tree(arg)
#     100                 canon_args += [canon_arg]
#     101                 constrs += c
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/cvxpy/reductions/canonicalization.py in canonicalize_tree(self, expr)
#      97             constrs = []
#      98             for arg in expr.args:
# ---> 99                 canon_arg, c = self.canonicalize_tree(arg)
#     100                 canon_args += [canon_arg]
#     101                 constrs += c
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/cvxpy/reductions/canonicalization.py in canonicalize_tree(self, expr)
#      97             constrs = []
#      98             for arg in expr.args:
# ---> 99                 canon_arg, c = self.canonicalize_tree(arg)
#     100                 canon_args += [canon_arg]
#     101                 constrs += c
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/cvxpy/reductions/canonicalization.py in canonicalize_tree(self, expr)
#     100                 canon_args += [canon_arg]
#     101                 constrs += c
# --> 102             canon_expr, c = self.canonicalize_expr(expr, canon_args)
#     103             constrs += c
#     104         return canon_expr, constrs
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/cvxpy/reductions/canonicalization.py in canonicalize_expr(self, expr, args)
#     113             return self.canon_methods[type(expr)](expr, args)
#     114         else:
# --> 115             return expr.copy(args), []
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/cvxpy/utilities/canonical.py in copy(self, args, id_objects)
#      95         data = self.get_data()
#      96         if data is not None:
# ---> 97             return type(self)(*(args + data))
#      98         else:
#      99             return type(self)(*args)
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/cvxpy/atoms/affine/index.py in __init__(self, expr, key, orig_key)
#      52             self._orig_key = orig_key
#      53             self.key = key
# ---> 54         super(index, self).__init__(expr)
#      55
#      56     def is_atom_log_log_convex(self) -> bool:
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/cvxpy/atoms/atom.py in __init__(self, *args)
#      49         self.args = [Atom.cast_to_const(arg) for arg in args]
#      50         self.validate_arguments()
# ---> 51         self._shape = self.shape_from_args()
#      52         if len(self._shape) > 2:
#      53             raise ValueError("Atoms must be at most 2D.")
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/cvxpy/atoms/affine/index.py in shape_from_args(self)
#      78         """Returns the shape of the index expression.
#      79         """
# ---> 80         return ku.shape(self.key, self._orig_key, self.args[0].shape)
#      81
#      82     def get_data(self):
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/cvxpy/utilities/key_utils.py in shape(key, orig_key, shape)
#     186             dims.append(1)
#     187         else:
# --> 188             size = int(np.ceil((key[i].stop - key[i].start)/key[i].step))
#     189             if size > 1 or i >= len(orig_key) or isinstance(orig_key[i], slice):
#     190                 dims.append(max(size, 0))
#
# KeyboardInterrupt:

# %%
print(np.sum(Tbar))
# Out:
# 547.3098769307317

# %%
t_index = [np.sum(Tbar[:i])  for i in range(N+1)]
fig = plt.figure(1,figsize=(15,7))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

ax.plot(x[:, 0], x[:, 1], x[:, 2],label='single shooting')
ax.plot(xbar[:, 0], xbar[:, 1], xbar[:, 2],label='solution')
plt.legend()
fig = plt.figure(2,figsize=(15,5))
ax = fig.add_subplot(131)
ax.plot(x[:, 0], x[:, 1],label='single shooting')
ax.plot(xbar[:, 0], xbar[:, 1],label='solution')
ax.set_xlabel('X')
ax.set_ylabel('Y')
plt.legend()
ax = fig.add_subplot(132)
ax.plot(x[:, 1], x[:, 2],label='single shooting')
ax.plot(xbar[:, 1], xbar[:, 2],label='solution')
ax.set_xlabel('Y')
ax.set_ylabel('Z')
ax = fig.add_subplot(133)
ax.plot(x[:, 0], x[:, 2],label='single shooting')
ax.plot(xbar[:, 0], xbar[:, 2],label='solution')
ax.set_xlabel('X')
ax.set_ylabel('Z')
plt.legend()
# ax.plot(xbar[:, 0], xbar[:, 1], xbar[:, 2],'o')

# %%
np.abs(x[-1] - xbar[-1])
# Out:
# array([7.16312491e-01, 1.16389017e+00, 1.46428513e-01, 1.24644283e-04,
#        7.93442152e-06, 8.04210993e-06])

# %%
plt.figure(figsize=(15,15))
plt.subplot(331)
plt.plot(t_index,xbar[:,0],label='solution')
plt.plot(t_index,x[:,0],'--',label='single shooting')
plt.legend(fontsize=15)
plt.title('x (m)')

plt.subplot(332)
plt.plot(t_index,xbar[:,1])
plt.plot(t_index,x[:,1],'--')
plt.title('y (m)')

plt.subplot(333)
plt.plot(t_index,xbar[:,2])
plt.plot(t_index,x[:,2],'--')
plt.title('z (m)')


plt.subplot(334)
plt.plot(t_index,xbar[:,3])
plt.plot(t_index,x[:,3],'--')
plt.plot(t_index,ubar[:,2]*0 + myConst.v_max,'--',color='tab:red')
plt.plot(t_index,ubar[:,2]*0 + myConst.v_min,'--',color='tab:red')
plt.title('velocity (m/s)')

plt.subplot(335)
plt.plot(t_index,xbar[:,4])
plt.plot(t_index,x[:,4],'--')
plt.plot(t_index,ubar[:,2]*0 + myConst.gamma_max,'--',color='tab:red')
plt.plot(t_index,ubar[:,2]*0 + myConst.gamma_min,'--',color='tab:red')
plt.title('gamma (rad)')

plt.subplot(336)
plt.plot(t_index,xbar[:,5])
plt.plot(t_index,x[:,5],'--')
plt.title('psi (rad)')

plt.subplot(337)
plt.plot(t_index,ubar[:,0],'o-')
# plt.plot(t_index,ubar[:,2]*0 + myConst.CL_max,'--',color='tab:red')
# plt.plot(t_index,ubar[:,2]*0 + myConst.CL_min,'--',color='tab:red')
plt.title('CL')
plt.plot(t_index,u0[:,0],'--',label='initial')
plt.legend(fontsize=15)
plt.subplot(338)
plt.plot(t_index,ubar[:,1],'o-')
plt.plot(t_index,ubar[:,2]*0 + myConst.phi_max,'--',color='tab:red')
plt.plot(t_index,ubar[:,2]*0 + myConst.phi_min,'--',color='tab:red')
plt.title('phi (rad)')
plt.plot(t_index,u0[:,1],'--',label='initial')
plt.subplot(339)
plt.plot(t_index,ubar[:,2],'o-')
plt.plot(t_index,ubar[:,2]*0 + myConst.T_max,'--',color='tab:red')
plt.plot(t_index,ubar[:,2]*0 + myConst.T_min,'--',color='tab:red')
plt.title('thrust (N)')
plt.plot(t_index,u0[:,2],'--',label='initial')

# %%
T = 15.04 - 0.00649 * xbar[:,2] # celsius
p = 101.29 * np.power((T+273.1)/288.08,5.256)
rho = p / (0.2869 * (T + 273.1))

F_lift = 0.5 * rho * xbar[:,3] * xbar[:,3] * myModel.Sw * ubar[:,0]
F_draf = 0.5 * rho * xbar[:,3] * xbar[:,3] * myModel.Sw * (myModel.CD0 + myModel.K  * ubar[:,0] * ubar[:,0])

# %%
plt.figure(figsize=(7,7))
plt.plot(t_index,rho)

# %%
plt.figure(figsize=(15,15))
plt.subplot(338)
plt.plot(t_index,F_lift)
plt.title('Lift force (N)')

plt.subplot(339)
plt.plot(t_index,F_draf)
plt.title('Drag force (N)')

# %%
for ubar_ in u_traj :
    plt.plot(t_index,ubar_[:,2],alpha=0.5,color='tab:blue')
# plt.title('CL')

# %%
a = np.random.randn(3,2,3)
print(a)
print()
b = np.array([1,2,3])
print((a.T*b).T)
