# %%
import matplotlib.pyplot as plt
# %matplotlib inline  
# %load_ext autoreload
# %autoreload 2
import numpy as np
import time
import random
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
#     print ("Values are: \n%s" % (x))

# %%
import sys
# sys.path.append('../')
sys.path.append('../')
sys.path.append('../model')
sys.path.append('../cost')
sys.path.append('../constraints')
import UnicycleModel
import UnicycleCost
import UnicycleConstraints
from scipy.integrate import solve_ivp
from Scvx import Scvx

# %%
ix = 3
iu = 2
ih = 2
N = 100
delT = 0.1
max_iter = 100

# %%
xi = np.zeros(3)
xi[0] = -2.0
xi[1] = -2.0 
xi[2] = np.pi/2

xf = np.zeros(3)
xf[0] = 2.0
xf[1] = 2.0
xf[2] = 0

myModel = UnicycleModel.unicycle('Hello',ix,iu,delT)
myCost = UnicycleCost.unicycle('Hello',ix,iu,N)
myConst = UnicycleConstraints.UnicycleConstraints('Hello',ix,iu,ih)

x0 = np.zeros((N+1,ix))
for i in range(N+1) :
    x0[i] = (N-i)/N * xi + i/N * xf
# u0 = np.random.rand(N,iu)
u0 = np.zeros((N,iu))

# %%
i1 = Scvx('unicycle',N,max_iter,myModel,myCost,myConst)
x, u = i1.update(x0,u0)
# Out:
# iteration   cost        cost_vc   cost_tr   reduction    expected    radius_tr
# 0           0           3e+05       0           3e+05       3e+05       1.0
# Boundary conditions are not satisified: just accept this step
# 1           254         1.3e-06     85.2        124         124         2.0
# Boundary conditions are not satisified: just accept this step
# 2           199         8.35e-07    16.2        4.17        4.17        4.0
# Boundary conditions are not satisified: just accept this step
# 3           207         9.59e-07    4.5         1.77        1.77        8.0
# Boundary conditions are not satisified: just accept this step
# 4           208         2e-06       1.62        0.0731      0.0731      16.0
# Boundary conditions are not satisified: just accept this step
# 5           209         4.39e-07    0.663       0.0303      0.0303      32.0
# Boundary conditions are not satisified: just accept this step
# non-positive expected reduction: should not occur
# 6           209         1.08e-06    0.299       -0.0935     -0.0935     64.0
# Boundary conditions are not satisified: just accept this step
# non-positive expected reduction: should not occur
# 7           209         1.15e-07    0.142       -0.169      -0.169      32.0
# Boundary conditions are not satisified: just accept this step
# non-positive expected reduction: should not occur
# 8           210         2.89e-06    0.268       -0.483      -0.483      16.0
# Boundary conditions are not satisified: just accept this step
# non-positive expected reduction: should not occur
# 9           210         2.69e-06    0.468       -0.642      -0.642      8.0
# non-positive expected reduction: should not occur
# 10          210         8.58e-06    0.62        -0.487      -0.487      4.0
# 11          211         3.62e-06    0.231       0.19        0.19        2.0
# 12          211         0.0018      0.00294     0.00297     0.00297     4.0
# 13          211         0.00177     2.79e-08    0.00739     0.00739     8.0
# 14          211         1.49e-05    0.0397      0.0412      0.0412      16.0
# 15          211         5.21e-06    0.0229      0.0178      0.0178      32.0
# 16          211         4.48e-05    0.00176     0.00273     0.00273     64.0
# 17          211         2.12e-05    0.00248     0.00185     0.00185     128.0
# 18          211         2.63e-05    0.000188    0.000256    0.000256    256.0
# 19          211         3.4e-05     0.000166    0.000204    0.000204    512.0
# 20          211         3.2e-05     5.95e-05    9.46e-05    9.46e-05    1024.0
# non-positive expected reduction: should not occur
# 21          211         1.29e-05    1.79e-05    -1.59e-06   -1.59e-06   2048.0
# non-positive expected reduction: should not occur
# 22          211         3.94e-05    5.58e-06    -8.26e-06   -8.26e-06   1024.0
# 23          211         5.42e-05    3.54e-07    4.99e-05    4.99e-05    512.0
# non-positive expected reduction: should not occur
# 24          211         4.03e-06    2.21e-08    -3.6e-05    -3.6e-05    1024.0
# 25          211         4.04e-05    2.67e-07    3.63e-05    3.63e-05    512.0
# non-positive expected reduction: should not occur
# 26          211         3.85e-06    2.5e-08     -2.91e-05   -2.91e-05   1024.0
# 27          211         3.32e-05    2.17e-07    2.94e-05    2.94e-05    512.0
# non-positive expected reduction: should not occur
# 28          211         3.65e-06    2.43e-08    -2.47e-05   -2.47e-05   1024.0
# 29          211         2.86e-05    1.83e-07    2.5e-05     2.5e-05     512.0
# non-positive expected reduction: should not occur
# 30          211         3.45e-06    2.29e-08    -2.15e-05   -2.15e-05   1024.0
# 31          211         2.52e-05    1.58e-07    2.18e-05    2.18e-05    512.0
# non-positive expected reduction: should not occur
# 32          211         3.27e-06    2.14e-08    -1.91e-05   -1.91e-05   1024.0
# 33          211         2.26e-05    1.38e-07    1.94e-05    1.94e-05    512.0
# non-positive expected reduction: should not occur
# 34          211         3.12e-06    1.99e-08    -2.86e-05   -2.86e-05   1024.0
# 35          211         3.19e-05    5.53e-07    2.95e-05    2.95e-05    512.0
# non-positive expected reduction: should not occur
# 36          211         2.51e-06    1.19e-08    -2.44e-05   -2.44e-05   1024.0
# 37          211         2.7e-05     4.09e-07    2.5e-05     2.5e-05     512.0
# non-positive expected reduction: should not occur
# 38          211         2.07e-06    8.29e-09    -2.14e-05   -2.14e-05   1024.0
# 39          211         2.36e-05    3.2e-07     2.18e-05    2.18e-05    512.0
# non-positive expected reduction: should not occur
# 40          211         1.85e-06    7.41e-09    -1.91e-05   -1.91e-05   1024.0
# 41          211         2.11e-05    2.61e-07    1.93e-05    1.93e-05    512.0
# non-positive expected reduction: should not occur
# 42          211         1.77e-06    8.23e-09    -1.72e-05   -1.72e-05   1024.0
# 43          211         1.91e-05    2.18e-07    1.74e-05    1.74e-05    512.0
# non-positive expected reduction: should not occur
# 44          211         1.68e-06    8.41e-09    -1.57e-05   -1.57e-05   1024.0
# 45          211         1.75e-05    1.86e-07    1.59e-05    1.59e-05    512.0
# non-positive expected reduction: should not occur
# 46          211         1.61e-06    8.57e-09    -1.44e-05   -1.44e-05   1024.0
# 47          211         1.62e-05    1.62e-07    1.46e-05    1.46e-05    512.0
# non-positive expected reduction: should not occur
# 48          211         1.56e-06    9.03e-09    -1.34e-05   -1.34e-05   1024.0
# 49          211         1.51e-05    1.42e-07    1.34e-05    1.34e-05    512.0
# non-positive expected reduction: should not occur
# 50          211         1.57e-06    9.49e-09    -1.24e-05   -1.24e-05   1024.0
# 51          211         1.41e-05    1.26e-07    1.25e-05    1.25e-05    512.0
# non-positive expected reduction: should not occur
# 52          211         1.59e-06    9.85e-09    -1.16e-05   -1.16e-05   1024.0
# 53          211         1.33e-05    1.13e-07    1.16e-05    1.16e-05    512.0
# non-positive expected reduction: should not occur
# 54          211         1.61e-06    1.02e-08    -1.08e-05   -1.08e-05   1024.0
# 55          211         1.25e-05    1.02e-07    1.09e-05    1.09e-05    512.0
# non-positive expected reduction: should not occur
# 56          211         1.62e-06    1.05e-08    -1.02e-05   -1.02e-05   1024.0
# 57          211         1.19e-05    9.24e-08    1.02e-05    1.02e-05    512.0
# non-positive expected reduction: should not occur
# 58          211         1.64e-06    1.07e-08    -9.56e-06   -9.56e-06   1024.0
# 59          211         1.13e-05    8.38e-08    9.58e-06    9.58e-06    512.0
# SUCCEESS: cost change < tolFun 9.580397818209547e-06

# %%
plt.figure(figsize=(10,10))
fS = 18
plt.subplot(221)
plt.plot(x[:,0], x[:,1], linewidth=2.0)
# plt.plot(x_t[0],x_t[1],"o",label='goal')
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([-3, 3, -3, 3])
plt.xlabel('X (m)', fontsize = fS)
plt.ylabel('Y (m)', fontsize = fS)
plt.subplot(222)
plt.plot(np.array(range(N+1))*0.1, x[:,0], linewidth=2.0,label='naive')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x1 (m)', fontsize = fS)
plt.subplot(223)
plt.plot(np.array(range(N+1))*0.1, x[:,1], linewidth=2.0,label='naive')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x2 (m)', fontsize = fS)
plt.subplot(224)
plt.plot(np.array(range(N+1))*0.1, x[:,2], linewidth=2.0,label='naive')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x3 (rad)', fontsize = fS)
plt.legend(fontsize=fS)
plt.show()

plt.figure()
plt.subplot(121)
plt.plot(np.array(range(N))*0.1, u[:,0], linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('v (m/s)', fontsize = fS)
plt.subplot(122)
plt.plot(np.array(range(N))*0.1, u[:,1], linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('w (rad/s)', fontsize = fS)
plt.show()

# %%
a = np.vstack((np.ones((10,2)),np.zeros(2)))
print_np(a)
